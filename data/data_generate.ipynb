# %% [markdown]
# # 数据集生成
#
# 生成CSV数据表, 定义数据大小为$D = 20, l = 10000 $

# %% [markdown]
# ### Exampe1
#
# Given $\vec{p}, \vec{q}, Find: $
# $$
# y = sin(<\bold{p}, \bold{x}>) + cos(<\bold{q}, \bold{x}>)
# $$

# %%
import numpy as np
import pandas as pd

# %%
# 设置随机数种子
np.random.seed(42)

# %%
D = 40
# 定义p,q为随机数数组
p = np.random.rand(D)
q = np.random.rand(D)

# %%
def func1(p, q, x):
    return np.sin(np.dot(p, x)) + np.cos(np.dot(q, x))

# 生成数据10000个样本, x为0-1的随机数
X = np.random.rand(10000, D)
# 计算y
y = np.array([func1(p, q, x) for x in X])

# %%
# 标准化数据
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.reshape(-1, 1)).reshape(-1)

# %%
# 保存数据
df = pd.DataFrame(np.hstack([X, y.reshape(-1, 1)]))
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.250107  0.432554 -0.578400 -1.513010 -0.669289 -0.608792  0.804890
# 1  1.058146  1.377502 -0.623408 -1.351336 -0.956631 -0.258621  1.111579
# 2 -0.458058  0.463756  0.477930  0.129045 -1.432883  1.143771 -0.613325
# 3  0.487717 -1.435076 -1.169231  1.390551  0.352955 -1.694393 -1.374105
# 4  1.516874  1.577849  1.459923 -0.446858 -1.691805  1.463337 -0.240741
#
#          7         8         9   ...        31        32        33        34  \
# 0  0.477470  1.346126 -0.095303  ... -1.177931  1.459452  1.064232  0.473094
# 1  1.248884 -1.707337  0.039080  ... -0.906663 -1.256201 -0.042359  1.684977
# 2 -1.081578 -1.590011  0.318591  ...  1.370581  1.358135  0.456469 -0.539681
# 3  0.567149 -1.713895 -1.181347  ...  0.004282  0.238679 -0.031716 -1.034371
# 4  1.615019  1.611169  1.232733  ...  1.068974  1.242749  1.429268  0.053149
#
#          35        36        37        38        39        40
# ...

# %%
# 检验数据
print(df.describe())
# Out:
#                  0             1             2             3             4   \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean  -1.058957e-14  5.460521e-15  8.697043e-16  7.168666e-15 -6.041745e-15
# std    1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00
# min   -1.726049e+00 -1.726020e+00 -1.733265e+00 -1.733476e+00 -1.744936e+00
# 25%   -8.631114e-01 -8.711409e-01 -8.642318e-01 -8.671187e-01 -8.646919e-01
# 50%    6.766554e-03  3.674242e-03  3.587360e-03 -5.867705e-03  8.537315e-03
# 75%    8.675733e-01  8.620147e-01  8.573026e-01  8.548901e-01  8.700628e-01
# max    1.721211e+00  1.736938e+00  1.756730e+00  1.743059e+00  1.714203e+00
#
#                  5             6             7             8             9   \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean   7.787548e-16  1.094236e-16 -5.362111e-15  2.254552e-15 -2.078870e-15
# ...

# %%
# 保存数据
df.to_csv('Exampe1_D40.csv', index=False, header=['X'+str(i) for i in range(D)]+['y'])
